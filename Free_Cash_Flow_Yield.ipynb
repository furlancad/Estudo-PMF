# %% [markdown]
# <a href="https://colab.research.google.com/github/furlancad/Estudo-PMF/blob/main/Free_Cash_Flow_Yield.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <center><img src = "https://github.com/Trading-com-Dados/pmf/blob/main/logotipo-trading-com-dados.svg?raw=true" width = "300">
#
#
#
# ---

# %% [markdown]
# # **Demonstração de cálculo de métricas fundamentalistas**

# %% [markdown]
# Muitas métricas fundamentalistas utilizadas no dia a dia do mercado financeiro para tomada de decisão de investimento não são encontradas facilmente, diretamente nos balanços e demonstrativos.
#
# Isso porque essas métricas são derivadas, ou seja, utilizam variáveis obtidas nos demonstrativos e balanços e colocadas em fórmulas para fins de criação de índices, razões, etc.
#
# Normalmente, conseguimos obter os dados de balanços e demonstrativos. Como fazer então para calcular uma dessas métricas derivadas para várias empresas ao mesmo tempo?

# %% [markdown]
# ## 0. Introdução

# %% [markdown]
# <center><img src = "https://republicsmetoolkit.com/wp-content/uploads/2019/09/cash-flow-projection.jpg?raw=true" width = "300">

# %% [markdown]
# ### **Free Cash Flow (Fluxo de Caixa)**

# %% [markdown]
# O dinheiro que a empresa tem disponível para repassar aos credores ou pagar dividendos e juros para investidores.
# Representa o caixa que uma empresa gera após contabilizar as saídas de caixa para apoiar as operações e manter seus ativos de capital.

# %% [markdown]
# ### **Free Cash Flow Yield (Rendimento do Fluxo de Caixa Livre)**

# %% [markdown]
# Ao avaliar ações, a maioria dos investidores está familiarizada com indicadores fundamentalistas famosos, como o índice preço/lucro (P/L), valor contábil, preço/valor contábil (P/B) e o índice PEG. Além disso, os investidores que reconhecem a importância da geração de caixa utilizam as demonstrações de fluxo de caixa da empresa ao analisar seus fundamentos. Reconhecem que estas declarações oferecem uma melhor representação das operações da empresa.
#
# No entanto, muito poucas pessoas analisam quanto fluxo de caixa livre (FCF) está disponível em relação ao valor da empresa.
#
# Chamado de rendimento do fluxo de caixa livre (Free Cash Flow Yield, ou FCFY), é um indicador melhor do que o índice P/L.

# %% [markdown]
# <center><img src = "https://www.investopedia.com/thmb/QCI4TrdgWKZXY6NDqe3bp_b9BX0=/1500x0/filters:no_upscale():max_bytes(150000):strip_icc()/freecashflowyield.asp-FINAL-ff037b79fb4b41a3b72c95f5ce051662.png?raw=true" width = "500">

# %% [markdown]
# O índice P/L mede quanto lucro líquido anual está disponível por ação ordinária. No entanto, a demonstração do fluxo de caixa é uma medida melhor do desempenho de uma empresa do que a demonstração do resultado.

# %% [markdown]
# Existe uma ferramenta de medição comparável ao índice P/L que utiliza a demonstração do fluxo de caixa?
#
# Felizmente, sim. Podemos usar o fluxo de caixa livre e dividi-lo pelo valor da empresa como um indicador mais confiável. Chamado de rendimento do fluxo de caixa livre, isso oferece aos investidores outra maneira de avaliar o valor de uma empresa que é comparável ao índice P/L. Como esta medida utiliza o fluxo de caixa livre, o rendimento do fluxo de caixa livre fornece uma medida melhor do desempenho de uma empresa.
#
# A maneira mais comum de calcular o rendimento do fluxo de caixa livre é usar a capitalização de mercado como divisor.

# %% [markdown]
# \begin{align}
#         \text{Free Cash Flow Yield} = \frac{\text{Free Cash Flow (Fluxo de Caixa Livre) }}{\text{Market Capitalization (Valor de Mercado)}}
#     \end{align}

# %% [markdown]
# Geralmente, quanto menor a proporção do resultado, menos atraente é o investimento, e vice-versa. A lógica é, os investidores preferem obviamente pagar o menor preço possível pelo maior número de ganho possível.

# %% [markdown]
# ---

# %% [markdown]
# #### Sources:

# %% [markdown]
# Free Cash Flow:
#
# https://www.investopedia.com/terms/f/freecashflow.asp
#
#
# Free Cash Flow Yield:
#
# https://www.investopedia.com/articles/fundamental-analysis/09/free-cash-flow-yield.asp
#
# https://andrebona.com.br/buggpedia-o-que-e-o-free-cash-flow-to-yield/
#
# https://www.shopify.com/blog/free-cash-flow-yield
#
# Free Cash Flow Margin:
#
# https://www.wallstreetprep.com/knowledge/fcf-margin/

# %% [markdown]
# ## 1. Importação das bibliotecas

# %%
import pandas as pd
import yfinance as yf

# %% [markdown]
# ## 2. Explorar funcionalidades básicas da yfinance

# %%
grnd = yf.Ticker('GRND3.SA')

# %%
grnd.basic_info
# Out:
# lazy-loading dict with keys = ['currency', 'dayHigh', 'dayLow', 'exchange', 'fiftyDayAverage', 'lastPrice', 'lastVolume', 'marketCap', 'open', 'previousClose', 'quoteType', 'regularMarketPreviousClose', 'shares', 'tenDayAverageVolume', 'threeMonthAverageVolume', 'timezone', 'twoHundredDayAverage', 'yearChange', 'yearHigh', 'yearLow']

# %%
grnd.financials
# Out:
#                                                           2022-12-31  \
# Tax Effect Of Unusual Items                           1331256.837535
# Tax Rate For Calcs                                          0.012671
# Normalized EBITDA                                        572781000.0
# Total Unusual Items                                      105061000.0
# Total Unusual Items Excluding Goodwill                   105061000.0
# Net Income From Continuing Operation Net Minori...       568027000.0
# Reconciled Depreciation                                   93746000.0
# Reconciled Cost Of Revenue                              1504894000.0
# EBITDA                                                   677842000.0
# EBIT                                                     584096000.0
# Net Interest Income                                       88945000.0
# Interest Expense                                           8779000.0
# Interest Income                                           42056000.0
# Normalized Income                                   464297256.837535
# Net Income From Continuing And Discontinued Ope...       568027000.0
# Total Expenses                                          2255788000.0
# Rent Expense Supplemental                                  2837000.0
# Total Operating Income As Reported                       239120000.0
# Diluted Average Shares                                   902472623.0
# Basic Average Shares                                     901875993.0
# Diluted EPS                                                   0.6294
# Basic EPS                                                     0.6298
# Diluted NI Availto Com Stockholders                      568027000.0
# Net Income Common Stockholders                           568027000.0
# Otherunder Preferred Stock Dividend                              0.0
# Net Income                                               568027000.0
# Net Income Including Noncontrolling Interests            568027000.0
# Net Income Continuous Operations                         568027000.0
# Tax Provision                                              7290000.0
# Pretax Income                                            575317000.0
# Special Income Charges                                           NaN
# Other Special Charges                                            NaN
# Net Non Operating Interest Income Expense                 88945000.0
# Total Other Finance Cost                                 -55668000.0
# Interest Expense Non Operating                             8779000.0
# Interest Income Non Operating                             42056000.0
# Operating Income                                         256868000.0
# Operating Expense                                        750894000.0
# Other Operating Expenses                                  63065000.0
# Depreciation And Amortization In Income Statement         29712000.0
# Depreciation Income Statement                             29712000.0
# Selling General And Administration                       542108000.0
# Selling And Marketing Expense                            522105000.0
# General And Administrative Expense                        20003000.0
# Rent And Landing Fees                                      2837000.0
# Gross Profit                                            1007762000.0
# Cost Of Revenue                                         1504894000.0
# Total Revenue                                           2512656000.0
# Operating Revenue                                       2512656000.0
#
#                                                       2021-12-31  \
# Tax Effect Of Unusual Items                            7871680.0
# Tax Rate For Calcs                                          0.34
# Normalized EBITDA                                    626638000.0
# Total Unusual Items                                   23152000.0
# Total Unusual Items Excluding Goodwill                23152000.0
# Net Income From Continuing Operation Net Minori...   601005000.0
# Reconciled Depreciation                               91020000.0
# Reconciled Cost Of Revenue                          1312479000.0
# EBITDA                                               649790000.0
# EBIT                                                 558770000.0
# Net Interest Income                                   26720000.0
# Interest Expense                                       6041000.0
# Interest Income                                        3585000.0
# Normalized Income                                    585724680.0
# Net Income From Continuing And Discontinued Ope...   601005000.0
# Total Expenses                                      1956011000.0
# Rent Expense Supplemental                              3165000.0
# Total Operating Income As Reported                   393522000.0
# Diluted Average Shares                               902180661.0
# Basic Average Shares                                 901995525.0
# Diluted EPS                                               0.6662
# Basic EPS                                                 0.6663
# Diluted NI Availto Com Stockholders                  601005000.0
# Net Income Common Stockholders                       601005000.0
# Otherunder Preferred Stock Dividend                          0.0
# Net Income                                           601005000.0
# Net Income Including Noncontrolling Interests        601005000.0
# Net Income Continuous Operations                     601005000.0
# Tax Provision                                        -48276000.0
# Pretax Income                                        552729000.0
# Special Income Charges                                       NaN
# Other Special Charges                                        NaN
# Net Non Operating Interest Income Expense             26720000.0
# Total Other Finance Cost                             -29176000.0
# Interest Expense Non Operating                         6041000.0
# Interest Income Non Operating                          3585000.0
# Operating Income                                     386535000.0
# Operating Expense                                    643532000.0
# Other Operating Expenses                              43788000.0
# Depreciation And Amortization In Income Statement     31452000.0
# Depreciation Income Statement                         31452000.0
# Selling General And Administration                   455175000.0
# Selling And Marketing Expense                        437874000.0
# General And Administrative Expense                    17301000.0
# Rent And Landing Fees                                  3165000.0
# Gross Profit                                        1030067000.0
# Cost Of Revenue                                     1312479000.0
# Total Revenue                                       2342546000.0
# Operating Revenue                                   2342546000.0
#
#                                                       2020-12-31    2019-12-31
# Tax Effect Of Unusual Items                           -2347488.0      440013.0
# Tax Rate For Calcs                                         0.076         0.069
# Normalized EBITDA                                    565440000.0   611452000.0
# Total Unusual Items                                  -30888000.0     6377000.0
# Total Unusual Items Excluding Goodwill               -30888000.0     6377000.0
# Net Income From Continuing Operation Net Minori...   405206000.0   494954000.0
# Reconciled Depreciation                               88049000.0    77222000.0
# Reconciled Cost Of Revenue                          1022330000.0  1126511000.0
# EBITDA                                               534552000.0   617829000.0
# EBIT                                                 446503000.0   540607000.0
# Net Interest Income                                   26935000.0    35240000.0
# Interest Expense                                       7891000.0     9007000.0
# Interest Income                                       13307000.0     2128000.0
# Normalized Income                                    433746512.0   489017013.0
# Net Income From Continuing And Discontinued Ope...   405206000.0   494954000.0
# Total Expenses                                      1552513000.0  1724682000.0
# Rent Expense Supplemental                              2197000.0    10859000.0
# Total Operating Income As Reported                           NaN           NaN
# Diluted Average Shares                               902289099.0   903222223.0
# Basic Average Shares                                 901694863.0   901798750.0
# Diluted EPS                                               0.4491         0.907
# Basic EPS                                                 0.4494        0.9084
# Diluted NI Availto Com Stockholders                  405206000.0   494954000.0
# Net Income Common Stockholders                       405206000.0   494954000.0
# Otherunder Preferred Stock Dividend                          0.0           0.0
# Net Income                                           405206000.0   494954000.0
# Net Income Including Noncontrolling Interests        405206000.0   494954000.0
# Net Income Continuous Operations                     405206000.0   494954000.0
# Tax Provision                                         33406000.0    36646000.0
# Pretax Income                                        438612000.0   531600000.0
# Special Income Charges                               -47980000.0           NaN
# Other Special Charges                                 47980000.0           NaN
# Net Non Operating Interest Income Expense             26935000.0    35240000.0
# Total Other Finance Cost                             -21519000.0   -42119000.0
# Interest Expense Non Operating                         7891000.0     9007000.0
# Interest Income Non Operating                         13307000.0     2128000.0
# Operating Income                                     344272000.0   346352000.0
# Operating Expense                                    530183000.0   598171000.0
# Other Operating Expenses                              33500000.0    42872000.0
# Depreciation And Amortization In Income Statement     30584000.0    21216000.0
# Depreciation Income Statement                         30584000.0    21216000.0
# Selling General And Administration                   370582000.0   468305000.0
# Selling And Marketing Expense                        355332000.0   452859000.0
# General And Administrative Expense                    15250000.0    15446000.0
# Rent And Landing Fees                                  2197000.0    10859000.0
# Gross Profit                                         874455000.0   944523000.0
# Cost Of Revenue                                     1022330000.0  1126511000.0
# Total Revenue                                       1896785000.0  2071034000.0
# Operating Revenue                                   1896785000.0  2071034000.0

# %%
grnd.quarterly_financials
# Out:
#                                                      2023-06-30  \
# Tax Effect Of Unusual Items                                 0.0
# Tax Rate For Calcs                                     0.209025
# Normalized EBITDA                                   118181000.0
# Total Unusual Items                                         NaN
# Total Unusual Items Excluding Goodwill                      NaN
# Net Income From Continuing Operation Net Minori...   57246000.0
# Reconciled Depreciation                              24333000.0
# Reconciled Cost Of Revenue                          274073000.0
# EBITDA                                              118181000.0
# EBIT                                                 93848000.0
# Net Interest Income                                  72363000.0
# Interest Expense                                     21474000.0
# Interest Income                                      93837000.0
# Normalized Income                                    57246000.0
# Net Income From Continuing And Discontinued Ope...   57246000.0
# Total Expenses                                      443709000.0
# Rent Expense Supplemental                                   NaN
# Total Operating Income As Reported                          NaN
# Diluted Average Shares                              901511811.0
# Basic Average Shares                                901511811.0
# Diluted EPS                                              0.0635
# Basic EPS                                                0.0635
# Diluted NI Availto Com Stockholders                  57246000.0
# Net Income Common Stockholders                       57246000.0
# Otherunder Preferred Stock Dividend                         0.0
# Net Income                                           57246000.0
# Net Income Including Noncontrolling Interests        57246000.0
# Net Income Continuous Operations                     57246000.0
# Tax Provision                                        15128000.0
# Pretax Income                                        72374000.0
# Net Non Operating Interest Income Expense            72363000.0
# Total Other Finance Cost                                    NaN
# Interest Expense Non Operating                       21474000.0
# Interest Income Non Operating                        93837000.0
# Operating Income                                     19910000.0
# Operating Expense                                   169636000.0
# Other Operating Expenses                             11960000.0
# Depreciation And Amortization In Income Statement           NaN
# Depreciation Income Statement                               NaN
# Selling General And Administration                  160669000.0
# Selling And Marketing Expense                       134499000.0
# General And Administrative Expense                   26170000.0
# Rent And Landing Fees                                       NaN
# Gross Profit                                        189546000.0
# Cost Of Revenue                                     274073000.0
# Total Revenue                                       463619000.0
# Operating Revenue                                   463619000.0
#
#                                                           2023-03-31  \
# Tax Effect Of Unusual Items                           2856892.325649
# Tax Rate For Calcs                                          0.123766
# Normalized EBITDA                                        144566000.0
# Total Unusual Items                                       23083000.0
# Total Unusual Items Excluding Goodwill                    23083000.0
# Net Income From Continuing Operation Net Minori...       123117000.0
# Reconciled Depreciation                                   24423000.0
# Reconciled Cost Of Revenue                               301958000.0
# EBITDA                                                   167649000.0
# EBIT                                                     143226000.0
# Net Interest Income                                       31824000.0
# Interest Expense                                           2719000.0
# Interest Income                                            9587000.0
# Normalized Income                                   102890892.325649
# Net Income From Continuing And Discontinued Ope...       123117000.0
# Total Expenses                                           469927000.0
# Rent Expense Supplemental                                   849000.0
# Total Operating Income As Reported                               NaN
# Diluted Average Shares                                   903087287.0
# Basic Average Shares                                     901765493.0
# Diluted EPS                                                   0.1363
# Basic EPS                                                     0.1365
# Diluted NI Availto Com Stockholders                      123117000.0
# Net Income Common Stockholders                           123117000.0
# Otherunder Preferred Stock Dividend                              0.0
# Net Income                                               123117000.0
# Net Income Including Noncontrolling Interests            123117000.0
# Net Income Continuous Operations                         123117000.0
# Tax Provision                                             17390000.0
# Pretax Income                                            140507000.0
# Net Non Operating Interest Income Expense                 31824000.0
# Total Other Finance Cost                                 -24956000.0
# Interest Expense Non Operating                             2719000.0
# Interest Income Non Operating                              9587000.0
# Operating Income                                          50178000.0
# Operating Expense                                        167969000.0
# Other Operating Expenses                                  27999000.0
# Depreciation And Amortization In Income Statement          7073000.0
# Depreciation Income Statement                              7073000.0
# Selling General And Administration                        99966000.0
# Selling And Marketing Expense                             95164000.0
# General And Administrative Expense                         4802000.0
# Rent And Landing Fees                                       849000.0
# Gross Profit                                             218147000.0
# Cost Of Revenue                                          301958000.0
# Total Revenue                                            520105000.0
# Operating Revenue                                        520105000.0
#
#                                                      2022-12-31   2022-09-30
# Tax Effect Of Unusual Items                           -951600.0          0.0
# Tax Rate For Calcs                                          0.4      0.06926
# Normalized EBITDA                                   211509000.0  231802000.0
# Total Unusual Items                                  -2379000.0          NaN
# Total Unusual Items Excluding Goodwill               -2379000.0          NaN
# Net Income From Continuing Operation Net Minori...  202607000.0  174241000.0
# Reconciled Depreciation                              23918000.0   23363000.0
# Reconciled Cost Of Revenue                          413506000.0  429410000.0
# EBITDA                                              209130000.0  231802000.0
# EBIT                                                185212000.0  208439000.0
# Net Interest Income                                  32834000.0  122835000.0
# Interest Expense                                      2942000.0   21232000.0
# Interest Income                                       9380000.0  144067000.0
# Normalized Income                                   204034400.0  174241000.0
# Net Income From Continuing And Discontinued Ope...  202607000.0  174241000.0
# Total Expenses                                      627663000.0  640083000.0
# Rent Expense Supplemental                              708000.0          NaN
# Total Operating Income As Reported                  125324000.0   64372000.0
# Diluted Average Shares                              902290085.0  902335577.0
# Basic Average Shares                                901689648.0  901868530.0
# Diluted EPS                                              0.2245       0.1931
# Basic EPS                                                0.2247       0.1932
# Diluted NI Availto Com Stockholders                 202607000.0  174241000.0
# Net Income Common Stockholders                      202607000.0  174241000.0
# Otherunder Preferred Stock Dividend                         0.0          0.0
# Net Income                                          202607000.0  174241000.0
# Net Income Including Noncontrolling Interests       202607000.0  174241000.0
# Net Income Continuous Operations                    202607000.0  174241000.0
# Tax Provision                                       -20337000.0   12966000.0
# Pretax Income                                       182270000.0  187207000.0
# Net Non Operating Interest Income Expense            32834000.0  122835000.0
# Total Other Finance Cost                            -26396000.0          NaN
# Interest Expense Non Operating                        2942000.0   21232000.0
# Interest Income Non Operating                         9380000.0  144067000.0
# Operating Income                                    136010000.0   73784000.0
# Operating Expense                                   214157000.0  210673000.0
# Other Operating Expenses                             32288000.0    9403000.0
# Depreciation And Amortization In Income Statement     7021000.0          NaN
# Depreciation Income Statement                         7021000.0          NaN
# Selling General And Administration                  155313000.0  203842000.0
# Selling And Marketing Expense                       150774000.0  176459000.0
# General And Administrative Expense                    4539000.0   27383000.0
# Rent And Landing Fees                                  708000.0          NaN
# Gross Profit                                        350167000.0  284457000.0
# Cost Of Revenue                                     413506000.0  429410000.0
# Total Revenue                                       763673000.0  713867000.0
# Operating Revenue                                   763673000.0  713867000.0

# %%
grnd.quarterly_cash_flow
# Out:
#                                            2023-06-30   2023-03-31  \
# Free Cash Flow                            197516000.0  257610000.0
# Repurchase Of Capital Stock                       NaN          NaN
# Repayment Of Debt                        -153032000.0 -113152000.0
# Issuance Of Debt                           27588000.0  193536000.0
# Issuance Of Capital Stock                         0.0    2027000.0
# Capital Expenditure                       -27332000.0  -37570000.0
# End Cash Position                          54326000.0   16382000.0
# Beginning Cash Position                    16382000.0  127409000.0
# Changes In Cash                            37944000.0 -111027000.0
# Financing Cash Flow                     -1308256000.0   81799000.0
# Interest Paid Cff                        -110459000.0    -612000.0
# Cash Dividends Paid                               NaN          NaN
# Net Common Stock Issuance                         0.0    2027000.0
# Common Stock Payments                             NaN          NaN
# Common Stock Issuance                             0.0    2027000.0
# Net Issuance Payments Of Debt            -125444000.0   80384000.0
# Net Long Term Debt Issuance              -125444000.0   80384000.0
# Long Term Debt Payments                  -153032000.0 -113152000.0
# Long Term Debt Issuance                    27588000.0  193536000.0
# Investing Cash Flow                      1121352000.0 -488006000.0
# Interest Received Cfi                      61017000.0   12750000.0
# Net Investment Purchase And Sale         1088110000.0 -451621000.0
# Sale Of Investment                       1407050000.0  264844000.0
# Purchase Of Investment                   -318940000.0 -716465000.0
# Net Business Purchase And Sale              -443000.0  -11565000.0
# Purchase Of Business                        -443000.0  -11565000.0
# Net PPE Purchase And Sale                 -27332000.0  -37570000.0
# Purchase Of PPE                           -27332000.0  -37570000.0
# Operating Cash Flow                       224848000.0  295180000.0
# Taxes Refund Paid                          -6674000.0    4103000.0
# Change In Working Capital                 144425000.0  196151000.0
# Change In Other Current Assets               194000.0   -9856000.0
# Change In Accrued Expense                  11453000.0   -5025000.0
# Change In Payable                         -10537000.0  -30256000.0
# Change In Inventory                       -34689000.0    9475000.0
# Change In Receivables                     178004000.0  231813000.0
# Other Non Cash Items                      -45904000.0  -64775000.0
# Stock Based Compensation                     371000.0     514000.0
# Provisionand Write Offof Assets              640000.0     386000.0
# Deferred Tax                                8925000.0     322000.0
# Depreciation And Amortization              24333000.0   24423000.0
# Depreciation                               24333000.0   24423000.0
# Pension And Employee Benefit Expense              NaN     131000.0
# Gain Loss On Investment Securities          2727000.0    2638000.0
# Net Foreign Currency Exchange Gain Loss    -6968000.0   -7494000.0
# Net Income From Continuing Operations      57246000.0  123117000.0
#
#                                           2022-12-31    2022-09-30
# Free Cash Flow                           166117000.0   -99644000.0
# Repurchase Of Capital Stock                      0.0    -1586000.0
# Repayment Of Debt                        -91217000.0   -98210000.0
# Issuance Of Debt                          99448000.0   127616000.0
# Issuance Of Capital Stock                        0.0           0.0
# Capital Expenditure                      -49747000.0   -44845000.0
# End Cash Position                        127409000.0    25287000.0
# Beginning Cash Position                   25287000.0    21836000.0
# Changes In Cash                          102122000.0     3451000.0
# Financing Cash Flow                      -85260000.0     1712000.0
# Interest Paid Cff                        -34423000.0   -18463000.0
# Cash Dividends Paid                      -59068000.0    -7645000.0
# Net Common Stock Issuance                        0.0    -1586000.0
# Common Stock Payments                            0.0    -1586000.0
# Common Stock Issuance                            0.0           0.0
# Net Issuance Payments Of Debt              8231000.0    29406000.0
# Net Long Term Debt Issuance                8231000.0    29406000.0
# Long Term Debt Payments                  -91217000.0   -98210000.0
# Long Term Debt Issuance                   99448000.0   127616000.0
# Investing Cash Flow                      -28482000.0    56538000.0
# Interest Received Cfi                     48604000.0   125951000.0
# Net Investment Purchase And Sale         -27269000.0    -1971000.0
# Sale Of Investment                       940128000.0  1162612000.0
# Purchase Of Investment                  -967397000.0 -1164583000.0
# Net Business Purchase And Sale              -70000.0   -22597000.0
# Purchase Of Business                        -70000.0   -22597000.0
# Net PPE Purchase And Sale                -49747000.0   -44845000.0
# Purchase Of PPE                          -49747000.0   -44845000.0
# Operating Cash Flow                      215864000.0   -54799000.0
# Taxes Refund Paid                         -4653000.0           NaN
# Change In Working Capital                 14915000.0  -189525000.0
# Change In Other Current Assets            12067000.0    -1697000.0
# Change In Accrued Expense                -20355000.0    18221000.0
# Change In Payable                          1593000.0    31550000.0
# Change In Inventory                       96992000.0    30049000.0
# Change In Receivables                    -75382000.0  -267648000.0
# Other Non Cash Items                      -7265000.0   -86126000.0
# Stock Based Compensation                    802000.0      805000.0
# Provisionand Write Offof Assets             167000.0      349000.0
# Deferred Tax                             -22673000.0    -7669000.0
# Depreciation And Amortization             23918000.0    23363000.0
# Depreciation                              23918000.0    23363000.0
# Pension And Employee Benefit Expense             NaN           NaN
# Gain Loss On Investment Securities       -12294000.0   -12958000.0
# Net Foreign Currency Exchange Gain Loss   -1842000.0      802000.0
# Net Income From Continuing Operations    202607000.0   174241000.0

# %%
grnd.basic_info['marketCap']
# Out:
# 5665546099.04007

# %% [markdown]
# ## 3. Calcular métricas fundamentalistas derivadas

# %%
grnd_fcf = grnd.quarterly_cash_flow.loc['Free Cash Flow']

# %%
grnd_mktcap = grnd.basic_info['marketCap']

# %%
grnd_fcf/grnd_mktcap
# Out:
# 2023-06-30    0.034863
# 2023-03-31     0.04547
# 2022-12-31    0.029321
# 2022-09-30   -0.017588
# Name: Free Cash Flow, dtype: object

# %%
(grnd_fcf/grnd_mktcap)*100
# Out:
# 2023-06-30    3.486266
# 2023-03-31    4.546958
# 2022-12-31    2.932056
# 2022-09-30   -1.758771
# Name: Free Cash Flow, dtype: object

# %%
grnd_fcfy  = pd.DataFrame((grnd_fcf/grnd_mktcap)*100)

# %%
grnd_fcfy.columns = ['GRND']

# %%
grnd_fcfy
# Out:
#                 GRND
# 2023-06-30  3.486266
# 2023-03-31  4.546958
# 2022-12-31  2.932056
# 2022-09-30 -1.758771

# %%
grnd_fcfy = grnd_fcfy[::-1]

# %%
grnd_fcfy
# Out:
#                 GRND
# 2022-09-30 -1.758771
# 2022-12-31  2.932056
# 2023-03-31  4.546958
# 2023-06-30  3.486266

# %%
grnd_fcfy.plot();

# %%
ticker = 'WEGE3'
papel = yf.Ticker(ticker + '.SA')
papel_fcf = papel.quarterly_cash_flow.loc['Free Cash Flow']
papel_mktcap = papel.basic_info['marketCap']
papel_fcfy  = pd.DataFrame((papel_fcf/papel_mktcap)*100)
papel_fcfy.columns = [ticker]
papel_fcfy = papel_fcfy[::-1]

# %%
papel_fcfy
# Out:
#                WEGE3
# 2022-09-30  0.558614
# 2022-12-31  1.015102
# 2023-03-31  1.420913
# 2023-06-30  0.298458
# 2023-09-30  1.094386

# %% [markdown]
# # 4. Criando funções de generalização

# %%
ativos = ['GRND3', 'VULC3', 'ALPA4', 'ARZZ3', 'VALE3', 'WEGE3']

# %%
free_cash_flow_yield = pd.DataFrame()

for i in ativos:

  papel = yf.Ticker(i + '.SA')

  papel_fcf = papel.quarterly_cash_flow.loc['Free Cash Flow']
  papel_mktcap = papel.basic_info['marketCap']

  papel_fcfy = (papel_fcf/papel_mktcap)*100
  papel_fcfy = papel_fcfy.astype(float)
  papel_fcfy = round(papel_fcfy, 2)

  free_cash_flow_yield[i] = papel_fcfy

free_cash_flow_yield = free_cash_flow_yield[::-1]

# %%
free_cash_flow_yield
# Out:
#             GRND3  VULC3  ALPA4  ARZZ3  VALE3  WEGE3
# 2022-09-30  -1.76   1.02  -2.54  -0.92   0.72   0.56
# 2022-12-31   2.93   0.81  -7.74   0.16   0.04   1.02
# 2023-03-31   4.55   2.72  -3.97  -1.98   0.82   1.42
# 2023-06-30   3.49   1.18  -1.36   0.05   0.23   0.30

# %%
def fcfy(stocks):
  import pandas as pd
  import yfinance as yf

  free_cash_flow_yield = pd.DataFrame()

  for i in stocks:

    papel = yf.Ticker(i + '.SA')

    papel_fcf = papel.quarterly_cash_flow.loc['Free Cash Flow']
    papel_mktcap = papel.basic_info['marketCap']

    papel_fcfy = (papel_fcf/papel_mktcap)*100
    papel_fcfy = papel_fcfy.astype(float)
    papel_fcfy = round(papel_fcfy, 2)

    free_cash_flow_yield[i] = papel_fcfy

  free_cash_flow_yield = free_cash_flow_yield[::-1]

  return free_cash_flow_yield;

# %%
fcfy(['EQTL3', 'VALE3', 'RADL3', 'WEGE3', 'LREN3'])
# Out:
#             EQTL3  VALE3  RADL3  WEGE3  LREN3
# 2022-09-30   1.96   0.72  -0.21   0.56   0.21
# 2022-12-31   1.63   0.04   1.20   1.02   2.11
# 2023-03-31   1.33   0.82   0.39   1.42   0.14
# 2023-06-30   1.62   0.23   0.70   0.30   3.45

# %% [markdown]
# ## 5. Plotagem

# %%
data = fcfy(['EQTL3', 'VALE3', 'RADL3', 'WEGE3', 'LREN3', 'PETR4'])

# %%
data.index = data.index.strftime('%m/%Y')

# %%
data
# Out:
#          EQTL3  VALE3  RADL3  WEGE3  LREN3  PETR4
# 09/2022   1.96   0.72  -0.21   0.56   0.21   2.11
# 12/2022   1.63   0.04   1.20   1.02   2.11   1.93
# 03/2023   1.33   0.82   0.39   1.42   0.14   1.65
# 06/2023   1.62   0.23   0.70   0.30   3.45   1.40

# %% [markdown]
# Consulte outras possibilidades de paletas na documentação da plotly:
#
# https://plotly.com/python/discrete-color/

# %%
import plotly.graph_objects as go
import plotly.express as px

fig = go.Figure(data=[
    go.Bar(name='EQTL3', x=data.index, y=data['EQTL3'],marker_color=px.colors.qualitative.T10[0]),
    go.Bar(name='VALE3', x=data.index, y=data['VALE3'],marker_color=px.colors.qualitative.T10[9]),
    go.Bar(name='RADL3', x=data.index, y=data['RADL3'],marker_color=px.colors.qualitative.T10[4]),
    go.Bar(name='WEGE3', x=data.index, y=data['WEGE3'],marker_color=px.colors.qualitative.T10[3]),
    go.Bar(name='LREN3', x=data.index, y=data['LREN3'],marker_color=px.colors.qualitative.T10[8])
], layout=go.Layout(xaxis = {"type": "category"} ))

# Modificar o 'barmode' para agrupar as barras
fig.update_layout(title_text='Free Cash Flow Yield')
fig.update_layout(barmode='group')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="512d19b7-36fc-4f89-b30a-df024225442e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("512d19b7-36fc-4f89-b30a-df024225442e")) {                    Plotly.newPlot(                        "512d19b7-36fc-4f89-b30a-df024225442e",                        [{"marker":{"color":"#4C78A8"},"name":"EQTL3","x":["09\u002f2022","12\u002f2022","03\u002f2023","06\u002f2023"],"y":[1.96,1.63,1.33,1.62],"type":"bar"},{"marker":{"color":"#BAB0AC"},"name":"VALE3","x":["09\u002f2022","12\u002f2022","03\u002f2023","06\u002f2023"],"y":[0.72,0.04,0.82,0.23],"type":"bar"},{"marker":{"color":"#54A24B"},"name":"RADL3","x":["09\u002f2022","12\u002f2022","03\u002f2023","06\u002f2023"],"y":[-0.21,1.2,0.39,0.7],"type":"bar"},{"marker":{"color":"#72B7B2"},"name":"WEGE3","x":["09\u002f2022","12\u002f2022","03\u002f2023","06\u002f2023"],"y":[0.56,1.02,1.42,0.3],"type":"bar"},{"marker":{"color":"#9D755D"},"name":"LREN3","x":["09\u002f2022","12\u002f2022","03\u002f2023","06\u002f2023"],"y":[0.21,2.11,0.14,3.45],"type":"bar"}],                        {"xaxis":{"type":"category"},"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorb ...
